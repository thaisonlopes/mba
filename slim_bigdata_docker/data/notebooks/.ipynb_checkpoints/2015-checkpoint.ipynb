# %% [markdown]
# ## Limpeza de dados Cartola ano 2015

# %%
from pyspark.sql import HiveContext
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import lower, col, lit, regexp_replace
import pandas as pd
import json
import requests

# %% [markdown]
# ## Jogadores

# %%
#Carrega arquivo CSV
jogadores_2015_df = spark.read.csv("/cartola/data/2015/2015_jogadores.csv", header=True)
sorted_jogadores_2015_df = jogadores_2015_df.sort(jogadores_2015_df.ID.desc())

# %%
#Adiciona coluna ANO = 2015
#Clube ID está como NA????
jogadores_2015_ano = sorted_jogadores_2015_df.withColumn('ano', lit(2015))
jogadores_2015_ano.show()

# %%
jogadores_2015_ano.write.partitionBy('ano').parquet('/cartola/2015/clean/jogadores')

# %%
#transforma arquivo em parquet
jogadores_2015_parquet = spark.read.parquet('/cartola/2015/clean/jogadores')

# %%
jogadores_2015_parquet.show()
jogadores_2015_parquet.schema

# %%
#Alterar ID para int.(está string)
jogadores_2015_parquet = jogadores_2015_parquet.withColumn("ID", jogadores_2015_parquet["ID"].cast(IntegerType()))
jogadores_2015_parquet = jogadores_2015_parquet.withColumn("ClubeID", jogadores_2015_parquet["ClubeID"].cast(IntegerType()))
jogadores_2015_parquet = jogadores_2015_parquet.withColumn("PosicaoID", jogadores_2015_parquet["PosicaoID"].cast(IntegerType()))

# %%
jogadores_2015_parquet.schema

# %%
jogadores_2015_parquet.show()

print(jogadores_2015_parquet.count())

# %% [markdown]
# ## Partidas_IDS (temos partidas como NA)

# %%
partidas_ids_2015_df = spark.read.csv("/cartola/data/2015/2015_partidas_ids.csv", header=True)

# %%
partidas_ids_2015_ano = partidas_ids_2015_df.withColumn('ano', lit(2015))

# %%
partidas_ids_2015_ano.show(1000)
# Out:
# +------+------+------+-----------+----------+---------------+---------+----+
# |    ID|Rodada|CasaID|VisitanteID|PlacarCasa|PlacarVisitante|Resultado| ano|
# +------+------+------+-----------+----------+---------------+---------+----+
# |190053|     1|   276|        262|         2|              1|     Casa|2015|
# |190054|     1|   275|        282|         2|              2|   Empate|2015|
# |190055|     1|   266|        317|         1|              0|     Casa|2015|
# |190056|     1|   267|        290|         0|              0|   Empate|2015|
# |190057|     1|   284|        303|         3|              3|   Empate|2015|
# |190058|     1|   283|        264|         0|              1|Visitante|2015|
# |190059|     1|   314|        277|         1|              1|   Empate|2015|
# |190060|     1|   293|        285|         3|              0|     Casa|2015|
# |190061|     1|   292|        316|         4|              1|     Casa|2015|
# |190062|     1|   315|        294|         2|              1|     Casa|2015|
# |190063|     2|   264|        315|         1|              0|     Casa|2015|
# |190064|     2|   277|        283|         1|              0|     Casa|2015|
# |190065|     2|   303|        276|         1|              0|     Casa|2015|
# |190066|     2|   262|        292|         2|              2|   Empate|2015|
# |190067|     2|   285|        314|         1|              0|     Casa|2015|
# |190068|     2|   282|        266|         4|              1|     Casa|2015|
# |190069|     2|   316|        267|         0|              0|   Empate|2015|
# |190070|     2|   294|        284|         2|              0|     Casa|2015|
# |190071|     2|   290|        293|         2|              0|     Casa|2015|
# |190072|     2|   317|        275|         0|              0|   Empate|2015|
# |190073|     3|   276|        317|         3|              0|     Casa|2015|
# |190074|     3|   275|        290|         0|              1|Visitante|2015|
# |190075|     3|   266|        264|         0|              0|   Empate|2015|
# |190076|     3|   267|        285|         1|              1|   Empate|2015|
# |190077|     3|   284|        316|         1|              0|     Casa|2015|
# |190078|     3|   283|        303|         1|              1|   Empate|2015|
# |190079|     3|   314|        262|         2|              1|     Casa|2015|
# |190080|     3|   293|        282|         1|              0|     Casa|2015|
# |190081|     3|   292|        294|         1|              0|     Casa|2015|
# |190082|     3|   315|        277|         1|              0|     Casa|2015|
# |190083|     4|   264|        275|         0|              2|Visitante|2015|
# |190084|     4|   277|        292|         2|              2|   Empate|2015|
# |190085|     4|   303|        315|         3|              1|     Casa|2015|
# |190086|     4|   262|        266|         2|              3|Visitante|2015|
# |190087|     4|   285|        276|         0|              0|   Empate|2015|
# |190088|     4|   282|        267|         3|              0|     Casa|2015|
# |190089|     4|   316|        283|         2|              1|     Casa|2015|
# |190090|     4|   294|        314|         1|              2|Visitante|2015|
# |190091|     4|   290|        284|         1|              1|   Empate|2015|
# |190092|     4|   317|        293|         1|              2|Visitante|2015|
# |190093|     5|   276|        277|         3|              2|     Casa|2015|
# |190094|     5|   275|        285|         1|              1|   Empate|2015|
# |190095|     5|   266|        294|         2|              0|     Casa|2015|
# |190096|     5|   267|        303|         0|              3|Visitante|2015|
# |190097|     5|   284|        264|         3|              1|     Casa|2015|
# |190098|     5|   283|        262|         1|              0|     Casa|2015|
# |190099|     5|   314|        282|         1|              4|Visitante|2015|
# |190100|     5|   293|        316|         1|              0|     Casa|2015|
# |190101|     5|   292|        290|         1|              0|     Casa|2015|
# |190102|     5|   315|        317|         2|              0|     Casa|2015|
# |190103|     6|   276|        284|         2|              0|     Casa|2015|
# |190104|     6|   277|        303|         2|              2|   Empate|2015|
# |190105|     6|   266|        292|         0|              0|   Empate|2015|
# |190106|     6|   262|        315|         1|              0|     Casa|2015|
# |190107|     6|   285|        294|         2|              0|     Casa|2015|
# |190108|     6|   282|        283|         1|              3|Visitante|2015|
# |190109|     6|   316|        275|         2|              1|     Casa|2015|
# |190110|     6|   293|        267|         2|              0|     Casa|2015|
# |190111|     6|   290|        314|         0|              1|Visitante|2015|
# |190112|     6|   317|        264|         0|              1|Visitante|2015|
# |190113|     7|   264|        285|         2|              1|     Casa|2015|
# |190114|     7|   275|        266|         2|              1|     Casa|2015|
# |190115|     7|   303|        290|         0|              0|   Empate|2015|
# |190116|     7|   267|        283|         1|              3|Visitante|2015|
# |190117|     7|   284|        293|         2|              1|     Casa|2015|
# |190118|     7|   282|        277|         2|              2|   Empate|2015|
# |190119|     7|   314|        316|         1|              1|   Empate|2015|
# |190120|     7|   294|        262|         0|              1|Visitante|2015|
# |190121|     7|   292|        317|         2|              1|     Casa|2015|
# |190122|     7|   315|        276|         0|              1|Visitante|2015|
# |190123|     8|   276|        314|         1|              1|   Empate|2015|
# |190124|     8|   277|        264|         1|              0|     Casa|2015|
# |190125|     8|   266|        303|         2|              0|     Casa|2015|
# |190126|     8|   262|        282|         0|              2|Visitante|2015|
# |190127|     8|   284|        275|         1|              0|     Casa|2015|
# |190128|     8|   283|        315|         0|              1|Visitante|2015|
# |190129|     8|   316|        285|         0|              0|   Empate|2015|
# |190130|     8|   293|        294|         2|              2|   Empate|2015|
# |190131|     8|   292|        267|         2|              1|     Casa|2015|
# |190132|     8|   317|        290|         2|              1|     Casa|2015|
# |190133|     9|   264|        316|         2|              1|     Casa|2015|
# |190134|     9|   275|        276|         4|              0|     Casa|2015|
# |190135|     9|   303|        293|         2|              1|     Casa|2015|
# |190136|     9|   267|        262|         1|              0|     Casa|2015|
# |190137|     9|   285|        277|         1|              0|     Casa|2015|
# |190138|     9|   282|        317|         1|              0|     Casa|2015|
# |190140|     9|   314|        284|         1|              2|Visitante|2015|
# |190141|     9|   294|        283|         1|              0|     Casa|2015|
# |190142|     9|   290|        266|         1|              2|Visitante|2015|
# |190143|     9|   315|        292|         1|              1|   Empate|2015|
# |190144|    10|   264|        303|         2|              0|     Casa|2015|
# |190145|    10|   275|        315|         2|              0|     Casa|2015|
# |190146|    10|   266|        277|         2|              1|     Casa|2015|
# |190147|    10|   267|        314|         1|              0|     Casa|2015|
# |190148|    10|   284|        283|         1|              0|     Casa|2015|
# |190149|    10|   282|        294|         2|              0|     Casa|2015|
# |190150|    10|   316|        290|         3|              1|     Casa|2015|
# |190151|    10|   293|        276|         2|              1|     Casa|2015|
# |190152|    10|   292|        285|         3|              0|     Casa|2015|
# |190153|    10|   317|        262|         0|              1|Visitante|2015|
# |190154|    11|   276|        266|         0|              0|   Empate|2015|
# |190155|    11|   277|        284|         1|              3|Visitante|2015|
# |190156|    11|   303|        275|         0|              2|Visitante|2015|
# |190157|    11|   262|        316|         1|              2|Visitante|2015|
# |190158|    11|   285|        282|         1|              3|Visitante|2015|
# |190159|    11|   283|        293|         2|              0|     Casa|2015|
# |190160|    11|   314|        292|         2|              2|   Empate|2015|
# |190161|    11|   294|        317|         0|              0|   Empate|2015|
# |190162|    11|   290|        264|         0|              0|   Empate|2015|
# |190163|    11|   315|        267|         1|              0|     Casa|2015|
# |190164|    12|   264|        293|         2|              0|     Casa|2015|
# |190165|    12|   275|        314|         3|              0|     Casa|2015|
# |190166|    12|   266|        283|         1|              0|     Casa|2015|
# |190167|    12|   267|        276|         0|              4|Visitante|2015|
# |190168|    12|   285|        262|         1|              2|Visitante|2015|
# |190169|    12|   282|        292|         2|              1|     Casa|2015|
# |190170|    12|   316|        317|         0|              2|Visitante|2015|
# |190171|    12|   294|        303|         0|              0|   Empate|2015|
# |190172|    12|   290|        277|         4|              1|     Casa|2015|
# |190173|    12|   315|        284|         1|              0|     Casa|2015|
# |190174|    13|   276|        294|         3|              1|     Casa|2015|
# |190175|    13|   277|        316|         3|              0|     Casa|2015|
# |190176|    13|   303|        282|         0|              2|Visitante|2015|
# |190177|    13|   262|        264|         0|              3|Visitante|2015|
# |190178|    13|   284|        267|         2|              0|     Casa|2015|
# |190179|    13|   283|        290|         1|              0|     Casa|2015|
# |190180|    13|   314|        315|         2|              1|     Casa|2015|
# |190181|    13|   293|        266|         1|              2|Visitante|2015|
# |190182|    13|   292|        275|         2|              2|   Empate|2015|
# |190183|    13|   317|        285|         0|              2|Visitante|2015|
# |190184|    14|   264|        282|         1|              0|     Casa|2015|
# |190185|    14|   275|        277|         1|              0|     Casa|2015|
# |190186|    14|   266|        267|         1|              2|Visitante|2015|
# |190187|    14|   262|        284|         1|              0|     Casa|2015|
# |190188|    14|   285|        290|         2|              1|     Casa|2015|
# |190189|    14|   283|        314|         1|              1|   Empate|2015|
# |190190|    14|   316|        294|         0|              0|   Empate|2015|
# |190191|    14|   292|        276|         2|              0|     Casa|2015|
# |190192|    14|   317|        303|         1|              1|   Empate|2015|
# |190193|    15|   276|        283|         1|              0|     Casa|2015|
# |190194|    15|   277|        317|         2|              0|     Casa|2015|
# |190195|    15|   303|        285|         0|              0|   Empate|2015|
# |190196|    15|   267|        275|         1|              4|Visitante|2015|
# |190197|    15|   284|        292|         1|              1|   Empate|2015|
# |190198|    15|   282|        316|         1|              0|     Casa|2015|
# |190199|    15|   314|        293|         1|              2|Visitante|2015|
# |190200|    15|   294|        264|         1|              1|   Empate|2015|
# |190201|    15|   290|        262|         0|              1|Visitante|2015|
# |190202|    15|   315|        266|         2|              1|     Casa|2015|
# |190203|    16|   264|        267|         3|              0|     Casa|2015|
# |190204|    16|   275|        293|         0|              1|Visitante|2015|
# |190205|    16|   266|        284|         1|              0|     Casa|2015|
# |190206|    16|   262|        277|         2|              2|   Empate|2015|
# |190207|    16|   285|        315|         0|              0|   Empate|2015|
# |190208|    16|   282|        276|         3|              1|     Casa|2015|
# |190209|    16|   316|        303|         3|              1|     Casa|2015|
# |190210|    16|   294|        290|         1|              1|   Empate|2015|
# |190211|    16|   292|        283|         0|              0|   Empate|2015|
# |190212|    16|   317|        314|         2|              0|     Casa|2015|
# |190213|    17|   276|        264|         1|              1|   Empate|2015|
# |190214|    17|   277|        294|         3|              0|     Casa|2015|
# |190215|    17|   267|        317|         0|              0|   Empate|2015|
# |190216|    17|   284|        285|         5|              0|     Casa|2015|
# |190217|    17|   283|        275|         2|              1|     Casa|2015|
# |190218|    17|   314|        266|         1|              0|     Casa|2015|
# |190219|    17|   293|        292|         1|              1|   Empate|2015|
# |190220|    17|   303|        262|         1|              0|     Casa|2015|
# |190221|    17|   290|        282|         0|              0|   Empate|2015|
# |190222|    17|   315|        316|         2|              2|   Empate|2015|
# |190223|    18|   264|        292|         4|              3|     Casa|2015|
# |190224|    18|   277|        267|         1|              0|     Casa|2015|
# |190225|    18|   303|        314|         2|              0|     Casa|2015|
# |190226|    18|   262|        293|         3|              2|     Casa|2015|
# |190227|    18|   285|        266|         1|              0|     Casa|2015|
# |190228|    18|   282|        284|         0|              2|Visitante|2015|
# |190229|    18|   316|        276|         0|              2|Visitante|2015|
# |190230|    18|   294|        275|         2|              1|     Casa|2015|
# |190231|    18|   290|        315|         0|              0|   Empate|2015|
# |190232|    18|   317|        283|         3|              0|     Casa|2015|
# |190233|    19|   276|        290|         0|              3|Visitante|2015|
# |190234|    19|   275|        262|         4|              2|     Casa|2015|
# |190235|    19|   266|        316|         2|              1|     Casa|2015|
# |190236|    19|   267|        294|         0|              1|Visitante|2015|
# |190237|    19|   284|        317|         2|              1|     Casa|2015|
# |190239|    19|   314|        264|         1|              2|Visitante|2015|
# |190240|    19|   293|        277|         0|              0|   Empate|2015|
# |190241|    19|   292|        303|         1|              1|   Empate|2015|
# |190242|    19|   315|        282|         2|              1|     Casa|2015|
# |190243|    19|   283|        285|         0|              0|   Empate|2015|
# |190244|    20|   264|        283|         3|              0|     Casa|2015|
# |190245|    20|   303|        284|         0|              0|   Empate|2015|
# |190246|    20|   277|        314|         5|              2|     Casa|2015|
# |190247|    20|   262|        276|         2|              1|     Casa|2015|
# |190248|    20|   285|        293|         2|              0|     Casa|2015|
# |190249|    20|   282|        275|         2|              1|     Casa|2015|
# |190250|    20|   316|        292|         2|              1|     Casa|2015|
# |190251|    20|   294|        315|         1|              0|     Casa|2015|
# |190252|    20|   290|        267|         3|              0|     Casa|2015|
# |190253|    20|   317|        266|         2|              1|     Casa|2015|
# |190254|    21|   276|        303|         3|              0|     Casa|2015|
# |190255|    21|   275|        317|         3|              2|     Casa|2015|
# |190256|    21|   266|        282|         1|              2|Visitante|2015|
# |190257|    21|   267|        316|         0|              1|Visitante|2015|
# |190258|    21|   284|        294|         0|              0|   Empate|2015|
# |190259|    21|   283|        277|         0|              1|Visitante|2015|
# |190260|    21|   314|        285|         3|              0|     Casa|2015|
# |190261|    21|   293|        290|         3|              0|     Casa|2015|
# |190262|    21|   292|        262|         0|              1|Visitante|2015|
# |190263|    21|   315|        264|         1|              3|Visitante|2015|
# |190264|    22|   264|        266|         2|              0|     Casa|2015|
# |190265|    22|   277|        315|         3|              1|     Casa|2015|
# |190266|    22|   303|        283|         1|              2|Visitante|2015|
# |190267|    22|   262|        314|         3|              0|     Casa|2015|
# |190268|    22|   285|        267|         6|              0|     Casa|2015|
# |190269|    22|   282|        293|         0|              1|Visitante|2015|
# |190270|    22|   316|        284|         0|              2|Visitante|2015|
# |190271|    22|   294|        292|         0|              0|   Empate|2015|
# |190272|    22|   290|        275|         1|              0|     Casa|2015|
# |190273|    22|   317|        276|         0|              0|   Empate|2015|
# |190274|    23|   276|        285|         2|              0|     Casa|2015|
# |190275|    23|   275|        264|         3|              3|   Empate|2015|
# |190276|    23|   266|        262|         1|              3|Visitante|2015|
# |190277|    23|   267|        282|         1|              2|Visitante|2015|
# |190278|    23|   284|        290|         2|              1|     Casa|2015|
# |190279|    23|   283|        316|         5|              1|     Casa|2015|
# |190280|    23|   314|        294|         0|              2|Visitante|2015|
# |190281|    23|   293|        317|         0|              0|   Empate|2015|
# |190282|    23|   292|        277|         1|              1|   Empate|2015|
# |190283|    23|   315|        303|         0|              0|   Empate|2015|
# |190284|    24|   264|        284|         1|              1|   Empate|2015|
# |190285|    24|   277|        276|         3|              0|     Casa|2015|
# |190286|    24|   303|        267|         0|              1|Visitante|2015|
# |190287|    24|   262|        283|         2|              0|     Casa|2015|
# |190288|    24|   285|        275|         1|              0|     Casa|2015|
# |190289|    24|   282|        314|         2|              0|     Casa|2015|
# |190290|    24|   316|        293|         1|              1|   Empate|2015|
# |190291|    24|   294|        266|         1|              1|   Empate|2015|
# |190292|    24|   290|        292|         1|              0|     Casa|2015|
# |190293|    24|   317|        315|         0|              0|   Empate|2015|
# |190294|    25|   264|        317|         3|              0|     Casa|2015|
# |190295|    25|   275|        316|         2|              0|     Casa|2015|
# |190296|    25|   303|        277|         3|              1|     Casa|2015|
# |190297|    25|   267|        293|         2|              0|     Casa|2015|
# |190298|    25|   284|        276|         1|              2|Visitante|2015|
# |190299|    25|   283|        282|         1|              1|   Empate|2015|
# |190300|    25|   314|        290|         2|              1|     Casa|2015|
# |190301|    25|   294|        285|         0|              1|Visitante|2015|
# |190302|    25|   292|        266|         1|              0|     Casa|2015|
# |190303|    25|   315|        262|         1|              3|Visitante|2015|
# |190304|    26|   276|        315|        NA|             NA|       NA|2015|
# |190305|    26|   277|        282|        NA|             NA|       NA|2015|
# |190306|    26|   266|        275|        NA|             NA|       NA|2015|
# |190307|    26|   262|        294|        NA|             NA|       NA|2015|
# |190308|    26|   285|        264|        NA|             NA|       NA|2015|
# |190310|    26|   316|        314|        NA|             NA|       NA|2015|
# |190311|    26|   293|        284|        NA|             NA|       NA|2015|
# |190312|    26|   290|        303|        NA|             NA|       NA|2015|
# |190313|    26|   317|        292|        NA|             NA|       NA|2015|
# |190314|    27|   264|        277|         2|              0|     Casa|2015|
# |190315|    27|   275|        284|         3|              2|     Casa|2015|
# |190316|    27|   303|        266|         3|              1|     Casa|2015|
# |190317|    27|   267|        292|         2|              1|     Casa|2015|
# |190318|    27|   285|        316|         1|              1|   Empate|2015|
# |190319|    27|   282|        262|         4|              1|     Casa|2015|
# |190320|    27|   314|        276|         2|              1|     Casa|2015|
# |190321|    27|   294|        293|         2|              0|     Casa|2015|
# |190322|    27|   290|        317|         3|              0|     Casa|2015|
# |190323|    27|   315|        283|         0|              2|Visitante|2015|
# |190324|    28|   276|        275|         1|              1|   Empate|2015|
# |190325|    28|   277|        285|         3|              1|     Casa|2015|
# |190326|    28|   266|        290|         2|              0|     Casa|2015|
# |190327|    28|   262|        267|         1|              2|Visitante|2015|
# |190328|    28|   284|        314|         3|              1|     Casa|2015|
# |190329|    28|   283|        294|         2|              0|     Casa|2015|
# |190330|    28|   316|        264|         1|              3|Visitante|2015|
# |190331|    28|   293|        303|         1|              2|Visitante|2015|
# |190332|    28|   292|        315|         3|              0|     Casa|2015|
# |190333|    28|   317|        282|         2|              2|   Empate|2015|
# |190334|    29|   276|        293|         1|              0|     Casa|2015|
# |190335|    29|   277|        266|         3|              1|     Casa|2015|
# |190336|    29|   303|        264|         2|              2|   Empate|2015|
# |190337|    29|   262|        317|         2|              0|     Casa|2015|
# |190338|    29|   285|        292|         2|              1|     Casa|2015|
# |190339|    29|   283|        284|         0|              0|   Empate|2015|
# |190340|    29|   314|        267|         1|              1|   Empate|2015|
# |190341|    29|   294|        282|         0|              3|Visitante|2015|
# |190342|    29|   290|        316|         2|              3|Visitante|2015|
# |190343|    29|   315|        275|         5|              1|     Casa|2015|
# |190344|    30|   264|        290|         3|              0|     Casa|2015|
# |190345|    30|   275|        303|         0|              1|Visitante|2015|
# |190346|    30|   266|        276|         2|              0|     Casa|2015|
# |190347|    30|   267|        315|         1|              1|   Empate|2015|
# |190348|    30|   284|        277|         1|              0|     Casa|2015|
# |190349|    30|   282|        285|         2|              1|     Casa|2015|
# |190350|    30|   316|        262|         3|              0|     Casa|2015|
# |190351|    30|   293|        283|         2|              2|   Empate|2015|
# |190352|    30|   292|        314|         3|              0|     Casa|2015|
# |190353|    30|   317|        294|         3|              1|     Casa|2015|
# |190354|    31|   276|        267|         2|              2|   Empate|2015|
# |190355|    31|   277|        290|         3|              1|     Casa|2015|
# |190356|    31|   303|        294|         3|              0|     Casa|2015|
# |190357|    31|   262|        285|         0|              1|Visitante|2015|
# |190358|    31|   284|        315|         2|              3|Visitante|2015|
# |190359|    31|   283|        266|         2|              0|     Casa|2015|
# |190360|    31|   314|        275|         1|              3|Visitante|2015|
# |190361|    31|   293|        264|         1|              4|Visitante|2015|
# |190362|    31|   292|        282|         4|              1|     Casa|2015|
# |190363|    31|   317|        316|         1|              0|     Casa|2015|
# |190364|    32|   264|        262|         1|              0|     Casa|2015|
# |190365|    32|   275|        292|         0|              2|Visitante|2015|
# |190366|    32|   266|        293|         0|              1|Visitante|2015|
# |190367|    32|   267|        284|         0|              0|   Empate|2015|
# |190368|    32|   285|        317|         1|              0|     Casa|2015|
# |190369|    32|   282|        303|         2|              1|     Casa|2015|
# |190370|    32|   316|        277|         0|              0|   Empate|2015|
# |190371|    32|   294|        276|         1|              2|Visitante|2015|
# |190372|    32|   290|        283|         0|              1|Visitante|2015|
# |190373|    32|   315|        314|         0|              0|   Empate|2015|
# |190374|    33|   276|        292|         3|              0|     Casa|2015|
# |190375|    33|   277|        275|         2|              1|     Casa|2015|
# |190376|    33|   303|        317|         1|              0|     Casa|2015|
# |190377|    33|   267|        266|         0|              1|Visitante|2015|
# |190378|    33|   284|        262|         2|              0|     Casa|2015|
# |190379|    33|   282|        264|         0|              3|Visitante|2015|
# |190380|    33|   314|        283|         1|              1|   Empate|2015|
# |190381|    33|   294|        316|         1|              1|   Empate|2015|
# |190382|    33|   290|        285|         2|              1|     Casa|2015|
# |190383|    33|   315|        293|         0|              0|   Empate|2015|
# |190384|    34|   264|        294|         2|              1|     Casa|2015|
# |190385|    34|   275|        267|         0|              2|Visitante|2015|
# |190386|    34|   266|        315|         2|              3|Visitante|2015|
# |190387|    34|   262|        290|         4|              1|     Casa|2015|
# |190388|    34|   285|        303|         1|              0|     Casa|2015|
# |190389|    34|   283|        276|         2|              1|     Casa|2015|
# |190390|    34|   293|        314|         2|              1|     Casa|2015|
# |190391|    34|   316|        282|         0|              1|Visitante|2015|
# |190392|    34|   292|        284|         1|              0|     Casa|2015|
# |190393|    34|   317|        277|         0|              0|   Empate|2015|
# |190394|    35|   276|        282|         4|              2|     Casa|2015|
# |190395|    35|   277|        262|         0|              0|   Empate|2015|
# |190396|    35|   303|        316|         0|              1|Visitante|2015|
# |190397|    35|   267|        264|         1|              1|   Empate|2015|
# |190398|    35|   284|        266|         1|              0|     Casa|2015|
# |190399|    35|   283|        292|         3|              0|     Casa|2015|
# |190400|    35|   314|        317|         2|              1|     Casa|2015|
# |190401|    35|   293|        275|         3|              3|   Empate|2015|
# |190402|    35|   290|        294|         1|              3|Visitante|2015|
# |190403|    35|   315|        285|         1|              0|     Casa|2015|
# |190404|    36|   264|        276|         6|              1|     Casa|2015|
# |190405|    36|   275|        283|         1|              1|   Empate|2015|
# |190406|    36|   266|        314|         3|              1|     Casa|2015|
# |190407|    36|   262|        303|         1|              1|   Empate|2015|
# |190408|    36|   285|        284|         1|              0|     Casa|2015|
# |190409|    36|   282|        290|         2|              2|   Empate|2015|
# |190410|    36|   316|        315|         0|              0|   Empate|2015|
# |190411|    36|   294|        277|         1|              0|     Casa|2015|
# |190412|    36|   292|        293|         0|              0|   Empate|2015|
# |190413|    36|   317|        267|         1|              2|Visitante|2015|
# |190414|    37|   276|        316|         3|              2|     Casa|2015|
# |190415|    37|   275|        294|         0|              2|Visitante|2015|
# |190416|    37|   266|        285|         1|              1|   Empate|2015|
# |190417|    37|   267|        277|         1|              0|     Casa|2015|
# |190418|    37|   284|        282|         2|              1|     Casa|2015|
# |190419|    37|   283|        317|         3|              0|     Casa|2015|
# |190420|    37|   314|        303|         1|              0|     Casa|2015|
# |190421|    37|   293|        262|         3|              0|     Casa|2015|
# |190422|    37|   292|        264|         2|              0|     Casa|2015|
# |190423|    37|   315|        290|         1|              3|Visitante|2015|
# |190424|    38|   264|        314|        NA|             NA|       NA|2015|
# |190425|    38|   277|        293|        NA|             NA|       NA|2015|
# |190426|    38|   303|        292|        NA|             NA|       NA|2015|
# |190427|    38|   262|        275|        NA|             NA|       NA|2015|
# |190428|    38|   285|        283|        NA|             NA|       NA|2015|
# |190429|    38|   282|        315|        NA|             NA|       NA|2015|
# |190430|    38|   316|        266|        NA|             NA|       NA|2015|
# |190431|    38|   294|        267|        NA|             NA|       NA|2015|
# |190432|    38|   290|        276|        NA|             NA|       NA|2015|
# |190436|    14|   293|        315|         1|              0|     Casa|2015|
# |190437|    26|   283|        267|        NA|             NA|       NA|2015|
# |191150|    38|   317|        284|        NA|             NA|       NA|2015|
# +------+------+------+-----------+----------+---------------+---------+----+

# %%
partidas_ids_2015_ano.write.partitionBy('ano').parquet('/cartola/2015/clean/2015_partidas_ids')

# %%
partidas_ids_2015_parquet = spark.read.parquet('/cartola/2015/clean/2015_partidas_ids')

# %%
partidas_ids_2015_parquet.show(10000)
partidas_ids_2015_parquet.schema

# %%
partidas_ids_2015_parquet = partidas_ids_2015_parquet.withColumn("ID", partidas_ids_2015_parquet["ID"].cast(IntegerType()))
partidas_ids_2015_parquet = partidas_ids_2015_parquet.withColumn("Rodada", partidas_ids_2015_parquet["Rodada"].cast(IntegerType()))
partidas_ids_2015_parquet = partidas_ids_2015_parquet.withColumn("CasaID", partidas_ids_2015_parquet["CasaID"].cast(IntegerType()))
partidas_ids_2015_parquet = partidas_ids_2015_parquet.withColumn("VisitanteID", partidas_ids_2015_parquet["VisitanteID"].cast(IntegerType()))
partidas_ids_2015_parquet = partidas_ids_2015_parquet.withColumn("PlacarCasa", partidas_ids_2015_parquet["PlacarVisitante"].cast(IntegerType()))
partidas_ids_2015_parquet = partidas_ids_2015_parquet.withColumn("PlacarVisitante", partidas_ids_2015_parquet["PlacarVisitante"].cast(IntegerType()))

# %%
partidas_ids_2015_parquet.show()

print(partidas_ids_2015_parquet.count())

# %% [markdown]
# ## scouts_raw

# %%
scouts_raw_2015_df = spark.read.csv("/cartola/data/2015/2015_scouts_raw.csv", header=True)

# %%
scouts_raw_2015_ano = scouts_raw_2015_df.withColumn('ano', lit(2015))

# %%
scouts_raw_2015_ano.show(1000)

# %%
# remove todas as linhas com rodada == 0
scouts_raw_2015_ano_clean = scouts_raw_2015_ano[scouts_raw_2015_ano['Rodada'] > 0]

# %%
scouts_raw_2015_ano_clean.show(10000)

# %%
scouts_raw_2015_ano_clean.write.partitionBy('ano').parquet('/cartola/2015/clean/scouts_raw_2015')

# %%
scouts_raw_2015_parquet = spark.read.parquet('/cartola/2015/clean/scouts_raw_2015')

# %%
scouts_raw_2015_parquet.show(10000)
scouts_raw_2015_parquet.schema

# %%
#deve-se converter valores em BigDecimal?
scouts_raw_2015_parquet = scouts_raw_2015_parquet.withColumn("Rodada", scouts_raw_2015_parquet["Rodada"].cast(IntegerType()))
scouts_raw_2015_parquet = scouts_raw_2015_parquet.withColumn("ClubeID", scouts_raw_2015_parquet["ClubeID"].cast(IntegerType()))
scouts_raw_2015_parquet = scouts_raw_2015_parquet.withColumn("AtletaID", scouts_raw_2015_parquet["AtletaID"].cast(IntegerType()))
scouts_raw_2015_parquet = scouts_raw_2015_parquet.withColumn("Jogos", scouts_raw_2015_parquet["Jogos"].cast(IntegerType()))

# %%
scouts_raw_2015_parquet.show()

print(scouts_raw_2015_parquet.count())

# %% [markdown]
# ## Times

# %%
times_2015_df = spark.read.csv("/cartola/data/2015/2015_times.csv", header=True)

# %%
sorted_times_2015_df = times_2015_df.sort(times_2015_df.ID.desc())

# %%
times_2015_ano = sorted_times_2015_df.withColumn('ano', lit(2015))
times_2015_ano.show()

# %%
times_2015_ano.write.partitionBy('ano').parquet('/cartola/2015/clean/times')

# %%
times_2015_parquet = spark.read.parquet("/cartola/2015/clean/times")

# %%
times_2015_parquet.show()
times_2015_parquet.schema

#Alterar ID para int.(está string)

# %%
times_2015_parquet = times_2015_parquet.withColumn("ID", times_2015_parquet["ID"].cast(IntegerType()))

# %%
times_2015_parquet.schema

# %%
times_2015_parquet.show()

print(times_2015_parquet.count())

# %% [markdown]
# ## DEMONSTRAÇÃO

# %%
partidas_2014_df = spark.read.csv("/cartola/data/2014/2014_jogadores.csv", header=True)
partidas_2014_ct = partidas_2014_df.withColumn('time', regexp_replace('home_team', ' - RJ', ''))
final_partidas = partidas_2014_ct.withColumn('time_low', lower(col('time'))).show(truncate=False)

# %%
with_ano_partidas = partidas_2014_ct.withColumn('ano', lit(2014)).show(truncate=False)
with_ano_partidas.show()
